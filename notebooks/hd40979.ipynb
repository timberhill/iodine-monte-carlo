# %% [markdown]
# #### setup...

# %%
import sys, os
sys.path.append(os.path.join(os.path.abspath(''), ".."))
from scripts.measure_peaks import measure_bfps
from scripts.plotter import plot_periodograms

# %% [markdown]
# # HD 40979
#
# ## Periodograms

# %%
f, ax = plot_periodograms(hd=40979, rotation=7.8, nobs=39, range1=(100, 700), range2=(2, 30), base=-4)
