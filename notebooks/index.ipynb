# %% [markdown]
# ### Setup:

# %%
import sys, os
sys.path.append(os.path.join(os.path.abspath(''), ".."))
from scripts.measure_peaks import measure_bfps
from scripts.plotter import plot_periodograms

# %% [markdown]
# # HD 22049
#
# ## Periodograms

# %%
f, ax = plot_periodograms(hd=22049, rotation=11.68, nobs=104, range1=(500, 9900), range2=(2, 60), base=-5)

# %% [markdown]
# # HD 40979
#
# ## Periodograms

# %%
f, ax = plot_periodograms(hd=40979, rotation=7.8, nobs=39, range1=(500, 9900), range2=(2, 6000), base=-4)
